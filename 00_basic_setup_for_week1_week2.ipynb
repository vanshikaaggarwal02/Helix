# %% [markdown]
# # Pre-Session Setup
#
# Use this notebook to prepare yourself before the live session.
#
#
# ## What you will set up
#
# 1. Cursor
# 2. Git
# 3. Clone this repository
# 4. Install uv
# 5. Install python
# 6. Ollama + local model
# 7. Verify local LLM calls from Python

# %% [markdown]
# ## 1) Install Required Software
#
# Install these before running the rest of the notebook:
# - **Git**: https://git-scm.com/downloads
# - **Python 3.11+**: https://www.python.org/downloads/
# - **Cursor**: https://cursor.com/downloads
# - **VS code**: (optional if cursor doesn't work for you) - https://code.visualstudio.com
# after installing curso/vs code install 2 extensions
# 1. jupyter
# 2. python
#
# - **Ollama**: https://ollama.com/ (Important step)
# - **UV** : https://docs.astral.sh/uv/getting-started/installation/ - run uv sync
# -- install python extention and jupyter notebook in cursor
#
# After installation, restart Terminal (or Cursor) so commands are recognized.

# %% [markdown]
# ## 2) Verify Tools Are Installed
#
# Run these commands in terminal and check if they are installed
#
# git --version
# python3 --version
# ollama --version
# uv --version

# %% [markdown]
# ## 3) Clone the Course Repository
#
# If you already cloned it, skip to the next section.

# %%
# Run once on your machine (skip if you already have this repo)
# Official course repo:
# !git clone <repo name >
open the repo in cursor/vs code 
in vs code/cursor terminal run uv --version
if you see uv version -> run uv sync -> this would create a virtual environment and download all the packages in .venv/ folder 
or open powershell/terminal and navigate to repo path and uv sync
# Out:
# zsh:1: parse error near `>'

# %% [markdown]
# ## 4) Create and Activate Python Environment
#
# select kernel from right hand side choose .venv option

# %% [markdown]
# ## 5) Ollama Setup
#
# Simply visit [ollama.com](https://ollama.com) and install!
#
# Once complete, the ollama server should already be running locally.
# If you visit:
# [http://localhost:11434/](http://localhost:11434/)
#
# You should see the message `Ollama is running`.
#
# If not, bring up a new Terminal (Mac) or Powershell (Windows) and enter `ollama serve`
# And in another Terminal (Mac) or Powershell (Windows), enter `ollama pull llama3.2`
# Then try [http://localhost:11434/](http://localhost:11434/) again.
#
# If Ollama is slow on your machine, try using `llama3.2:1b` as an alternative. Run `ollama pull llama3.2:1b` from a Terminal or Powershell.
#
# **Important:** avoid `llama3.3` or `llama4` for basic home setup because they are much larger.
#
# **Jupyter / Cursor note:** The notebook kernel often has a **smaller `PATH`** than Terminal, so `!ollama ...` can say `command not found` even when Ollama works in Terminal. The next cell fixes `PATH` for this session.
#
#
# ## Troubleshooting
#
# 1. If `ollama` command is not found **in the notebook** but works in Terminal:
#    - use Terminal for `ollama pull` / `ollama run`.
#    - If it fails everywhere, reinstall Ollama and restart Cursor/vs code.
#
# 2. If model call fails with connection error:
#    - Start Ollama app, then run `ollama run llama3.2` once in Terminal.
#
# 3. If Python import fails for `openai`:
#    - Ensure requirements installed inside `.venv`.
#
# 4. If you get permission issues with Git clone:
#    - Check network/proxy settings or try cloning via SSH.

# %%
# Run the cell above first (PATH fix). Pull the model (safe to re-run).
# !ollama pull llama3.2
# if the  'bind: address already in use' that means ollama is working on your machine 
# at [http://localhost:11434/](http://localhost:11434/)

# !ollama serve
# Out:
# ]11;?\Error: listen tcp 127.0.0.1:11434: bind: address already in use

# %%
#this can take some time initially 
#if it is taking a lot of time run 'ollama run llama3.2 "hi"' on your terminal/powershell 
#if stll it takes time pull a smaller model-> run 'ollama run gemma:2b' on your terminal

# !ollama run llama3.2 "hi"
# Out:
# ]11;?\⠙ ⠹ ⠸ ⠼ ⠼ ⠴ ⠧ ⠇ ⠏ How can I assist you today?

# %%
# Optional: quick chat test. Run the PATH cell above first.
# Stop with the stop button in the notebook UI if it hangs.
#it usually takes more than 30-40 seconds sometimes 
# !ollama run gemma:2b "what is the capital of india"
# Out:
# ]11;?\⠙ ⠹ ⠸ ⠼ ⠼ ⠴ ⠧ ⠧ ⠇ ⠋ ⠋ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠇ ⠏ ⠙ ⠹ ⠸ ⠸ ⠼ ⠦ ⠦ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠦ ⠇ ⠏ ⠏ ⠙ ⠙ ⠹ ⠼ ⠼ ⠴ ⠧ ⠧ ⠏ ⠏ ⠙ ⠙ ⠸ ⠼ ⠼ ⠴ ⠦ ⠧ ⠏ ⠏ ⠋ ⠹ ⠹ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠸ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠸ ⠴ ⠴ ⠧ ⠧ ⠏ ⠏ ⠋ ⠙ ⠹ ⠸ ⠴ ⠴ ⠧ ⠧ ⠏ ⠏ ⠙ ⠙ ⠸ ⠼ ⠼ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠹ ⠼ ⠴ ⠦ ⠦ ⠧ ⠏ ⠋ ⠋ ⠹ ⠹ ⠼ ⠴ ⠦ ⠦ ⠇ ⠇ ⠋ ⠋ ⠹ ⠹ ⠸ ⠴ ⠦ ⠦ ⠇ ⠇ ⠋ ⠙ ⠹ ⠹ ⠼ ⠴ ⠦ ⠧ ⠇ ⠇ ⠏ ⠋ ⠙ ⠸ ⠼ ⠴ ⠴ ⠧ ⠧ ⠏ ⠏ ⠋ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠋ ⠹ ⠸ ⠸ ⠴ ⠦ ⠧ ⠇ ⠏ ⠏ ⠙ ⠙ ⠸ ⠼ ⠴ ⠦ ⠦ ⠇ ⠏ ⠏ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠦ ⠇ ⠏ ⠋ ⠋ ⠙ ⠸ ⠼ ⠴ ⠴ ⠦ ⠧ ⠏ ⠋ ⠋ ⠹ ⠸ ⠸ ⠼ ⠦ ⠧ ⠧ ⠏ ⠏ ⠋ ⠙ ⠸ ⠼ ⠼ ⠦ ⠦ ⠇ ⠇ ⠋ ⠋ ⠙ ⠸ ⠸ ⠼ ⠦ ⠦ ⠇ ⠇ ⠏ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠇ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠼ ⠦ ⠧ ⠇ ⠏ ⠋ ⠋ ⠹ The capital of India is New Delhi. It is the political and administrative c
# center of the country.

# %%
# !ollama run gemma:2b "which ollama model supports tool calling"
# Out:
# ]11;?\⠙ ⠹ The Ollama model does not support tool calling. Ollama focuses on providing
# providing a unified platform for organizing and managing multiple tools and
# and workflows, but it does not provide specific support for integrating ext
# external tools or calling them.

# %% [markdown]
# ## 6) Verify Python Can Call Ollama (OpenAI-Compatible API)
#
# Ollama exposes a local endpoint at `http://localhost:11434/`.
#
# No real API key is needed for Ollama; we pass a dummy value because the client expects one.

# %%
from openai import OpenAI


OLLAMA_BASE_URL = "http://localhost:11434/v1"

client = OpenAI(base_url=OLLAMA_BASE_URL, api_key="ollama")
response = client.chat.completions.create(
    model="llama3.2",
    messages=[{"role": "user", "content": "What is 2 + 2?"}],
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 = 4.

# %% [markdown]
# ## 7) Session-Ready Checklist
#
# You are ready if all are true:
#
# - [ ] Cursor opens and works
# - [ ] `git --version` works
# - [ ] Repo is cloned locally
# - [ ] `.venv` is created
# - [ ] Requirements installed successfully
# - [ ] `ollama pull llama3.2` completed
# - [ ] Python test call to Ollama returns a response
#
# If something fails, fix it before the live session so we can focus fully on building agents.

# %% [markdown]
# ## Types of prompts
#
# Models like GPT have been trained to receive instructions in a particular way.
#
# They expect to receive:
#
# **A system prompt** that tells them what task they are performing and what tone they should use
#
# **A user prompt** -- the conversation starter that they should reply to

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
# Define our user prompt

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %% [markdown]
# ## Messages
#
# The API from OpenAI expects to receive messages in a particular structure.
# Many of the other APIs share this structure:
#
# ```python
# [
#     {"role": "system", "content": "system message goes here"},
#     {"role": "user", "content": "user message goes here"}
# ]
# ```
# To give you a preview, the next 2 cells make a rather simple call - we won't stretch the mighty GPT (yet!)

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "What is 2 + 2?"}
]

client = OpenAI(base_url=OLLAMA_BASE_URL, api_key="ollama")
response = client.chat.completions.create(model="llama3.2", messages=messages)
response.choices[0].message.content
# Out:
# 'The answer to 2 + 2 is 4.'

# %% [markdown]
# ## First - let's talk about the Chat Completions API
#
# 1. The simplest way to call an LLM
# 2. It's called Chat Completions because it's saying: "here is a conversation, please predict what should come next"
# 3. The Chat Completions API was invented by OpenAI, but it's so popular that everybody uses it!

# %% [markdown]
# # What is the openai package?
# x
# It's known as a Python Client Library.
#
# It's nothing more than a wrapper around making this exact call to the http endpoint.
#
# It just allows you to work with nice Python code instead of messing around with janky json objects.
#
# But that's it. It's open-source and lightweight. Some people think it contains OpenAI model code - it doesn't!

# %%
# Create OpenAI client



client = OpenAI(base_url=OLLAMA_BASE_URL, api_key="ollama")
response = client.chat.completions.create(model="gemma:2b", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content
# Out:
# 'Sure! Here’s a fun fact: The population of the earth is estimated to be around 8 billion people. That’s a lot of people!'

# %%
# Get a fun fact

response = ollama.chat.completions.create(model="llama3.2", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content

# %% [markdown]
# # Gradio!
#
# Today we will build User Interfaces using the outrageously simple Gradio framework.
#
# Prepare for joy!
#
# Please note: your Gradio screens may appear in 'dark mode' or 'light mode' depending on your computer settings.

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# %%
import gradio as gr # oh yeah!

# %%
#need to check again if we need to include that in the session 

# Load environment variables in a file called .env
# Print the key prefixes to help with any debugging
# You can choose whichever providers you like - or all Ollama
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:8]}")
else:
    print("Google API Key not set")

# %%
# Connect to OpenAI, Anthropic and Google; comment out the Claude or Google lines if you're not using them

openai = OpenAI()

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)

# %%
# Let's wrap a call to GPT-4.1-mini in a simple function

system_message = "You are a helpful assistant"
OLLAMA_BASE_URL = "http://localhost:11434/v1"

client = OpenAI(base_url=OLLAMA_BASE_URL, api_key="ollama")
def message_ollama(prompt):
    messages = [{"role": "system", "content": system_message}, {"role": "user", "content": prompt}]
    response = client.chat.completions.create(model="llama3.2", messages=messages)
    return response.choices[0].message.content

# %%
# This can reveal the "training cut off", or the most recent date in the training data

message_ollama("What is today's date?")
# Out:
# "I'm not currently able to share the time or date in real-time. However, I can tell you that my knowledge cutoff is December 2023, so any information or answers I provide will be based on data up to that point. If you need to know the current date or time, I recommend checking a reliable third-party source, such as Google or another calendar service."

# %% [markdown]
# ## User Interface time!

# %%
# Adding share=True means that it can be accessed publically
# A more permanent hosting is available using a platform called Spaces from HuggingFace, which we will touch on next week
# NOTE: Some Anti-virus software and Corporate Firewalls might not like you using share=True. 
# If you're at work on on a work network, I suggest skip this test.

gr.Interface(fn=message_ollama, inputs="textbox", outputs="textbox", flagging_mode="never").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * Running on public URL: https://155f9455664bc025bd.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://155f9455664bc025bd.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Adding inbrowser=True opens up a new browser window automatically

gr.Interface(fn=message_ollama, inputs="textbox", outputs="textbox", flagging_mode="never").launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7864
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# And now - changing the function from "shout" to "message_gpt"

message_input = gr.Textbox(label="Your message:", info="Enter a message for ollama3.2", lines=7)
message_output = gr.Textbox(label="Response:", lines=8)

view = gr.Interface(
    fn=message_ollama,
    title="OLLAMA", 
    inputs=[message_input], 
    outputs=[message_output], 
    examples=["hello", "howdy"], 
    flagging_mode="never"
    )
view.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7866
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7866/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# # Conversational AI - aka Chatbot!

# %%
# imports

import os
from dotenv import load_dotenv
from openai import OpenAI
import gradio as gr

# %%
system_message = "You are a helpful assistant"

# %% [markdown]
# ## And now, writing a new callback
#
# We now need to write a function called:
#
# `chat(message, history)`
#
# Which will be a callback function we will give gradio.
#
# ### The job of this function
#
# Take a message, take the prior conversation, and return the response.

# %%
def chat(message, history):
    return "bananas"

# %%
gr.ChatInterface(fn=chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7870
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7870/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
#need to understand

def chat(message, history):
    return f"You said {message} and the history is {history} but I still say bananas"

# %%
gr.ChatInterface(fn=chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7881
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7881/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## OK! Let's write a slightly better chat callback!

# %%
OLLAMA_BASE_URL = "http://localhost:11434/v1"

client = OpenAI(base_url=OLLAMA_BASE_URL, api_key="ollama")
def chat(message, history):
    history = [{"role":h["role"], "content":h["content"]} for h in history]
    messages = [{"role": "system", "content": system_message}] + history + [{"role": "user", "content": message}]
    response = client.chat.completions.create(model="llama3.2", messages=messages)
    return response.choices[0].message.content

# %%
gr.ChatInterface(fn=chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7883
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7883/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## OK let's keep going!
#
# Using a system message to add context, and to give an example answer.. this is "one shot prompting" again

# %%
system_message = "You are a helpful assistant in a clothes store. You should try to gently encourage \
the customer to try items that are on sale. Hats are 60% off, and most other items are 50% off. \
For example, if the customer says 'I'm looking to buy a hat', \
you could reply something like, 'Wonderful - we have lots of hats - including several that are part of our sales event.'\
Encourage the customer to buy hats if they are unsure what to get."

# %%
gr.ChatInterface(fn=chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7884
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7884/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
#to be removed 
system_message += "\nIf the customer asks for shoes, you should respond that shoes are not on sale today, \
but remind the customer to look at hats!"

# %%
gr.ChatInterface(fn=chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7885
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7885/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
#to be decided 

def chat(message, history):
    history = [{"role":h["role"], "content":h["content"]} for h in history]
    relevant_system_message = system_message
    if 'belt' in message.lower():
        relevant_system_message += " The store does not sell belts; if you are asked for belts, be sure to point out other items on sale."
    
    messages = [{"role": "system", "content": relevant_system_message}] + history + [{"role": "user", "content": message}]

    stream = client.chat.completions.create(model="llama3.2", messages=messages, stream=True)

    response = ""
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        yield response

# %%
gr.ChatInterface(fn=chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7886
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7886/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## Tools
#
# Tools are an incredibly powerful feature provided by the frontier LLMs.
#
# With tools, you can write a function, and have the LLM call that function as part of its response.
#
# Sounds almost spooky.. we're giving it the power to run code on our machine?
#
# Well, kinda.

# %%
system_message = """
You are a helpful assistant for an Airline called FlightAI.
Give short, courteous answers, no more than 1 sentence.
Always be accurate. If you don't know the answer, say so.
"""

# %%
client = OpenAI(base_url=OLLAMA_BASE_URL, api_key="ollama")
def chat(message, history):
    history = [{"role":h["role"], "content":h["content"]} for h in history]
    messages = [{"role": "system", "content": system_message}] + history + [{"role": "user", "content": message}]
    response = client.chat.completions.create(model="llama3.2", messages=messages)
    return response.choices[0].message.content

gr.ChatInterface(fn=chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7893
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7893/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Let's start by making a useful function

ticket_prices = {"london": "$799", "paris": "$899", "tokyo": "$1400", "berlin": "$499"}

def get_ticket_price(destination_city):
    print(f"Tool called for city {destination_city}")
    price = ticket_prices.get(destination_city.lower(), "Unknown ticket price")
    return f"The price of a ticket to {destination_city} is {price}"

# %%
get_ticket_price("London")
# Out:
# Tool called for city London
# 'The price of a ticket to London is $799'

# %%
# There's a particular dictionary structure that's required to describe our function:
import json
price_function = {
    "name": "get_ticket_price",
    "description": "Get the price of a return ticket to the destination city.",
    "parameters": {
        "type": "object",
        "properties": {
            "destination_city": {
                "type": "string",
                "description": "The city that the customer wants to travel to",
            },
        },
        "required": ["destination_city"],
        "additionalProperties": False
    }
}

# %%
# And this is included in a list of tools:

tools = [{"type": "function", "function": price_function}]

# %%
tools
# Out:
# [{'type': 'function',
#   'function': {'name': 'get_ticket_price',
#    'description': 'Get the price of a return ticket to the destination city.',
#    'parameters': {'type': 'object',
#     'properties': {'destination_city': {'type': 'string',
#       'description': 'The city that the customer wants to travel to'}},
#     'required': ['destination_city'],
#     'additionalProperties': False}}}]

# %% [markdown]
# ## Getting OpenAI to use our Tool
#
# There's some fiddly stuff to allow OpenAI "to call our tool"
#
# What we actually do is give the LLM the opportunity to inform us that it wants us to run the tool.
#
# Here's how the new chat function looks:

# %%
client = OpenAI(base_url=OLLAMA_BASE_URL, api_key="ollama")
def chat(message, history):
    history = [{"role":h["role"], "content":h["content"]} for h in history]
    messages = [{"role": "system", "content": system_message}] + history + [{"role": "user", "content": message}]
    response = client.chat.completions.create(model="llama3.2", messages=messages, tools=tools)

    if response.choices[0].finish_reason=="tool_calls":
        message = response.choices[0].message
        response = handle_tool_call(message)
        messages.append(message)
        messages.append(response)
        response = client.chat.completions.create(model="llama3.2", messages=messages)
    
    return response.choices[0].message.content

# %%
# We have to write that function handle_tool_call:

def handle_tool_call(message):
    tool_call = message.tool_calls[0]
    if tool_call.function.name == "get_ticket_price":
        arguments = json.loads(tool_call.function.arguments)
        city = arguments.get('destination_city')
        price_details = get_ticket_price(city)
        response = {
            "role": "tool",
            "content": price_details,
            "tool_call_id": tool_call.id
        }
    return response

# %%
gr.ChatInterface(fn=chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7894
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7894/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Tool called for city London

# %% [markdown]
# ## Let's make a couple of improvements
#
# Handling multiple tool calls in 1 response
#
# Handling multiple tool calls 1 after another

# %%
def chat(message, history):
    history = [{"role":h["role"], "content":h["content"]} for h in history]
    messages = [{"role": "system", "content": system_message}] + history + [{"role": "user", "content": message}]
    response = client.chat.completions.create(model="llama3.2", messages=messages, tools=tools)

    if response.choices[0].finish_reason=="tool_calls":
        message = response.choices[0].message
        responses = handle_tool_calls(message)
        messages.append(message)
        messages.extend(responses)
        response = client.chat.completions.create(model="llama3.2", messages=messages)
    
    return response.choices[0].message.content

# %%
def handle_tool_calls(message):
    responses = []
    for tool_call in message.tool_calls:
        if tool_call.function.name == "get_ticket_price":
            arguments = json.loads(tool_call.function.arguments)
            city = arguments.get('destination_city')
            price_details = get_ticket_price(city)
            responses.append({
                "role": "tool",
                "content": price_details,
                "tool_call_id": tool_call.id
            })
    return responses

# %%
gr.ChatInterface(fn=chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7895
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7895/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Tool called for city London

# %%
def chat(message, history):
    history = [{"role":h["role"], "content":h["content"]} for h in history]
    messages = [{"role": "system", "content": system_message}] + history + [{"role": "user", "content": message}]
    response = client.chat.completions.create(model="llama3.2", messages=messages, tools=tools)

    while response.choices[0].finish_reason=="tool_calls":
        message = response.choices[0].message
        responses = handle_tool_calls(message)
        messages.append(message)
        messages.extend(responses)
        response = client.chat.completions.create(model="llama3.2", messages=messages, tools=tools)
    
    return response.choices[0].message.content

# %%
gr.ChatInterface(fn=chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7896
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7896/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Tool called for city London
